# %%
## Importing all required libraries

import tensorflow as tf
import tensorflow_datasets as tfds
import os
import datetime

# %%
## Define the directories and global constants

parent_dir = "/content"
FILE_NAMES = ['news.txt']

BUFFER_SIZE = 2000
BATCH_SIZE = 128
TAKE_SIZE = 200000

# %%
def labeler(example, index):
  return example, tf.cast(index, tf.int64)

# %%
labeled_data_sets = []

for i, file_name in enumerate(FILE_NAMES):
  lines_dataset = tf.data.TextLineDataset(os.path.join(parent_dir, file_name))
  labeled_dataset = lines_dataset.map(lambda ex: labeler(ex, i))
  labeled_data_sets.append(labeled_dataset)

all_labeled_data = labeled_data_sets[0]
for labeled_dataset in labeled_data_sets[1:]:
  all_labeled_data = all_labeled_data.concatenate(labeled_dataset)
  
all_labeled_data = all_labeled_data.shuffle(
    BUFFER_SIZE, reshuffle_each_iteration=False)

print("Dataset Items Before Encoding:")
print("-------------------------------")
for ex in all_labeled_data.take(2):
  print(ex)
print("-------------------------------")

tokenizer = tfds.deprecated.text.Tokenizer()

vocabulary_set = set()

for text_tensor, _ in all_labeled_data:
  some_tokens = tokenizer.tokenize(text_tensor.numpy())
  vocabulary_set.update(some_tokens)

vocab_size = len(vocabulary_set)

print("Vocabulary size.   :" + str(vocab_size))
print("-------------------------------")
print(vocabulary_set)
print("-------------------------------")

encoder = tfds.deprecated.text.TokenTextEncoder(vocabulary_set)

example_text = next(iter(all_labeled_data))[0].numpy()
print("Example Sentence:")
print("-------------------------------")
print(example_text)

print("Encoded Example Sentence:")
print("-------------------------------")
encoded_example = encoder.encode(example_text)
print(encoded_example)
# Out:
# Dataset Items Before Encoding:
# -------------------------------
# (<tf.Tensor: shape=(), dtype=string, numpy=b'dance Sexy Nukim fall'>, <tf.Tensor: shape=(), dtype=int64, numpy=0>)
# (<tf.Tensor: shape=(), dtype=string, numpy=b'bts member RM J Hope see sit audience'>, <tf.Tensor: shape=(), dtype=int64, numpy=0>)
# -------------------------------
# Vocabulary size.   :13375
# -------------------------------
# {'bangchan', 'kara', 'Spain', 'Hypebeast', 'Moment', 'storyline', 'intern', 'revealing', 'register', 'publicise', 'frontman', 'versatile', 'embody', 'SuperM', 'tba', 'disk', 'ItsBennyBlanco', 'Viewers', 'KILLER', 'acoustic', 'Sulli', 'how', 'sincerely', 'Taeyeon', 'pleasing', 'BRIT', 'LIZZO', 'period', 'Younha', 'filipino', 'Shop', 'beast', 'Truth', '싶지', 'vacate', 'ENFJ', 'Joonie', 'snazzy', 'Ruthless', 'enchant', 'chic', 'Taeyong', 'glamorous', '9th', 'Episodes', 'borahae', 'alphabet', 'Hangjunie', 'terrific', 'Jealousy', 'flourish', 'fearlessly', 'overdue', 'heavily', 'packing', 'covet', 'jm', 'Spider', 'That', 'Boombayah', 'Soyeon', 'fabulously', '10M', 'mixed', 'Azmi', 'Gang', 'limit', 'Wang', 'hue', 'attempt', 'monochrome', 'Energetic', 'thirst', 'Holy', 'Musician', 'eligibility', 'trot', 'topic', 'Boyness', 'posture', 'time', '90staeguk', 'Anitta', 'ambidextrous', 'Kaohsiung', 'waltzing', 'knowingly', 'Davichi', 'conjure', 'heated', 'Bonney', 'dependable', '1613757478713556994https', 'DANN', '6th', 'remake', 'Hoba', 'slate', 'Menu', 'Dae', 'cumulative', 'newspaper', 'go', 'vast', 'dad', 'normal', 'considerate', 'mission', 'bin', 'WAY', '5xisxvcbzewepisode', 'project', 'guesswork', 'achievable', 'adopt', 'staff', 'Celine', 'extra', 'dormant', 'function', 'supergroup', '52', 'vulnerable', 'judgmental', 'rise', 'terrify', 'fondly', 'bang', 'skillstwitter', 'LOVESTAY', 'MAX', 'wonho', 'parted', 'ME', 'scanner', 'Dreams', 'tracklist', 'ditch', 'Danger', 'glove', 'finger', 'purely', 'megamix', 'registry', 'frill', 'Andini_bbystay', 'sara', 'being', 'strive', 'Pia', 'shave', 'assembly', 'Order', 'miracle', 'Yodha', 'sonyeondan', 'immense', 'evaluate', 'numerous', 'amidst', 'MGM', 'g', 'P1Harmony', 'brag', 'Simpson', 'driving', 'Barcelona', 'Tina', 'Guinness', 'Kriti', 'translator', 'slab', 'nitro', 'hua', 'freedom', 'btstranslation7', 'Hoping', '1512659283951128576', 'VMin', 'skip', 'admission', '1511349022811897856', 'displeasure', 'letdown', 'vma', 'Shik', 'CRAZY', 'BEST', 'Henry', 'well', 'root', 'jhope', 'handmade', 'tomorrow', 'Office', 'manifesto', 'KIM', 'spectator', 'mutually', 'okay', 'shy', 'relive', 'BANGTAN', 'Bubl', 'sandstorm', 'jazzy', 'Nakamoto', 'granddaughter', 'respectful', '1600686817158000643o1jvlxymryealso', 'ender', 'edible', 'reactor', 'ouryoujungkook', 'Garosu', 'bravely', '1511004242454097923', 'Taejin', 'Sunday', 'saint', 'btob', 'TBH', 'Mumbai', 'battalion', 'teacher', 'Tokyo', 'fd', 'demonic', 'mould', 'string', 'leesora', 'episode', 'Minji', 'Heavenly', 'd', 'Brother', 'accurately', 'Fear', 'Seduction', 'etymologically', 'Beat', 'Insta', 'saudi', 'jwehope', 'hatred', 'outdated', 'cardio', 'newbie', 'aloud', 'GOOD', 'vocally', 'Ye', 'BHUBANESWAR', 'Doha', 'hesitate', 'Jennifer', 'entry', 'Kathiawadi', 'voicing', 'north', 'legendsTiger', 'controversial', 'Dionysus', 'neater', 'Epilogue', 'v_pintor', 'Eddie', 'candy', 'demise', 'browse', 'channel', 'seaweed', 'hassle', 'Y', 'jkhostagesituation', 'Villain', 'bask', 'condemn', 'Nani', 'rule', 'Hailey', 'pit', 'Concept', 'observer', 'idolize', 'Berlin', 'behaviour', '1593091599764189186ALSO', 'Delighted', 'text', 'wildlife', 'indiathe', 'MOAs', '90', '220', 'Noeasy', 'ping', 'Sana', 'tank', 'basketball', 'reunite', 'bangtannie', 'embed', 'fit', 'dazzle', 'surprise', 'similarly', 'REGIME', 'hide', '20', 'Lahore', 'universe', 'joonie', 'carving', 'lookalike', '135th', 'metaphorically', 'Christopher', 'S', 'DALLA', 'photobombe', 'confidante', 'Tok', 'Shiv', 'yawn', 'museum', 'payback', 'itune', 'INOX', 'Finland', 'profession', 'At', 'tick', 'YT', 'plan', 'Jr', 'iv', 'Jungkookah', 'inquire', 'Goodbye', 'Chairman', 'clothing', 'Yuta', 'bandmates', 'DAY6', 'thread', 'scottish', 'snapshot', 'affectionate', 'gambling', 'Epik', 'over', 'Majestic', 'constantly', 'Games', 'forecast', 'rating', 'Mein', 'sup', '1512586796659613702', 'Mysterious', 'suffocate', 'Veautiful', 'Suzy', 'Department', 'JinRM', 'suppress', 'Mouth', 'LINE', 'retire', 'landing', 'o', 'As', 'su ...
# -------------------------------
# Example Sentence:
# -------------------------------
# b'dance Sexy Nukim fall'
# Encoded Example Sentence:
# -------------------------------
# [1702, 5366, 2003, 11276]

# %%
def encode(text_tensor, label):
  encoded_text = encoder.encode(text_tensor.numpy())
  return encoded_text, label

# %%
def encode_map_fn(text, label):
  encoded_text, label = tf.py_function(encode, 
                                       inp=[text, label], 
                                       Tout=(tf.int64, tf.int64))
  return encoded_text, label

# %%
all_encoded_data = all_labeled_data.map(encode_map_fn)

# %%
# train_data = all_encoded_data.skip(TAKE_SIZE).shuffle(BUFFER_SIZE)
train_data = all_encoded_data.shuffle(BUFFER_SIZE)
train_data = train_data.padded_batch(BATCH_SIZE, padded_shapes=([2000],()))

test_data = all_encoded_data.take(TAKE_SIZE)
test_data = test_data.padded_batch(BATCH_SIZE, padded_shapes=([2000],()))


sample_text, sample_labels = next(iter(test_data))

print(sample_text[10])
print(sample_labels[10])

print(sample_text[11])
print(sample_labels[11])
# Out:
# tf.Tensor([2872 7262 1785 ...    0    0    0], shape=(2000,), dtype=int64)
# tf.Tensor(0, shape=(), dtype=int64)
# tf.Tensor([ 7919 10845 10058 ...     0     0     0], shape=(2000,), dtype=int64)
# tf.Tensor(0, shape=(), dtype=int64)

# %%
#Training a LSTM model to test the data pipeline
vocab_size += 1

model = tf.keras.Sequential()
model.add(tf.keras.layers.Embedding(vocab_size, 64))
model.add(tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(64)))

for units in [64, 64]:
  model.add(tf.keras.layers.Dense(units, activation='relu'))

# %%
# Output layer. The first argument is the number of labels.
model.add(tf.keras.layers.Dense(3, activation='softmax'))

optimizer = tf.keras.optimizers.Adam(learning_rate=0.005, amsgrad=True)


model.compile(optimizer= optimizer,
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'],
              run_eagerly=True)

log_dir="logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)


model.fit(train_data, epochs=10, steps_per_epoch=4, validation_data=test_data, callbacks=[tensorboard_callback])

eval_loss, eval_acc = model.evaluate(test_data)

print('\nEval loss: {:.3f}, Eval accuracy: {:.3f}'.format(eval_loss, eval_acc))
# Out:
# Epoch 1/10
# 4/4 [==============================] - 21s 6s/step - loss: 1.0006 - accuracy: 0.0000e+00 - val_loss: 0.9692 - val_accuracy: 0.0000e+00
# Epoch 2/10
# 4/4 [==============================] - 20s 6s/step - loss: 0.9508 - accuracy: 0.2500 - val_loss: 0.9205 - val_accuracy: 1.0000
# Epoch 3/10
# 4/4 [==============================] - 20s 6s/step - loss: 0.9027 - accuracy: 1.0000 - val_loss: 0.8735 - val_accuracy: 1.0000
# Epoch 4/10
# 4/4 [==============================] - 20s 6s/step - loss: 0.8564 - accuracy: 1.0000 - val_loss: 0.8283 - val_accuracy: 1.0000
# Epoch 5/10
# 4/4 [==============================] - 20s 6s/step - loss: 0.8119 - accuracy: 1.0000 - val_loss: 0.7850 - val_accuracy: 1.0000
# Epoch 6/10
# 4/4 [==============================] - 20s 6s/step - loss: 0.7694 - accuracy: 1.0000 - val_loss: 0.7438 - val_accuracy: 1.0000
# Epoch 7/10
# 4/4 [==============================] - 20s 7s/step - loss: 0.7289 - accuracy: 1.0000 - val_loss: 0.7045 - val_accuracy: 1.0000
# Epoch 8/10
# 4/4 [==============================] - 20s 7s/step - loss: 0.6903 - accuracy: 1.0000 - val_loss: 0.6672 - val_accuracy: 1.0000
# Epoch 9/10
# 4/4 [==============================] - 19s 6s/step - loss: 0.6538 - accuracy: 1.0000 - val_loss: 0.6319 - val_accuracy: 1.0000
# Epoch 10/10
# 4/4 [==============================] - 20s 7s/step - loss: 0.6193 - accuracy: 1.0000 - val_loss: 0.5986 - val_accuracy: 1.0000
# 140/140 [==============================] - 19s 135ms/step - loss: 0.5986 - accuracy: 1.0000
#
# Eval loss: 0.599, Eval accuracy: 1.000
